# %%
# %load_ext autoreload
# %autoreload 2

# %%
from templates import *
# Out:
# C:\Users\tsj_g\2021118_yoshiike\.venv\Lib\site-packages\torchaudio\backend\utils.py:74: UserWarning: No audio backend is available.
#   warnings.warn("No audio backend is available.")

# %%
device = 'cuda:0'
# conf = ffhq256_autoenc()
conf = ddpm()
# print(conf.name)
model = LitModel(conf)
state = torch.load(f'checkpoints/{conf.name}/last.ckpt', map_location='cpu')
model.load_state_dict(state['state_dict'], strict=False)
model.ema_model.eval()
model.ema_model.to(device)
# Out:
# Global seed set to 0
# Model params: 64.70 M
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 6
#       4 # print(conf.name)
#       5 model = LitModel(conf)
# ----> 6 state = torch.load(f'checkpoints/{conf.name}/last.ckpt', map_location='cpu')
#       7 model.load_state_dict(state['state_dict'], strict=False)
#       8 model.ema_model.eval()
#
# File ~\2021118_yoshiike\.venv\Lib\site-packages\torch\serialization.py:791, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     788 if 'encoding' not in pickle_load_args.keys():
#     789     pickle_load_args['encoding'] = 'utf-8'
# --> 791 with _open_file_like(f, 'rb') as opened_file:
#     792     if _is_zipfile(opened_file):
#     793         # The zipfile reader is going to advance the current file position.
#     794         # If we want to actually tail call to torch.jit.load, we need to
#     795         # reset back to the original position.
#     796         orig_position = opened_file.tell()
#
# File ~\2021118_yoshiike\.venv\Lib\site-packages\torch\serialization.py:271, in _open_file_like(name_or_buffer, mode)
#     269 def _open_file_like(name_or_buffer, mode):
#     270     if _is_path(name_or_buffer):
# --> 271         return _open_file(name_or_buffer, mode)
#     272     else:
#     273         if 'w' in mode:
#
# File ~\2021118_yoshiike\.venv\Lib\site-packages\torch\serialization.py:252, in _open_file.__init__(self, name, mode)
#     251 def __init__(self, name, mode):
# --> 252     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'checkpoints//last.ckpt'

# %%
data = ImageDataset('imgs_align', image_size=conf.img_size, exts=['jpg', 'JPG', 'png'], do_augment=False)
batch = data[2]['img'][None]

# %%
import matplotlib.pyplot as plt
plt.imshow(batch[0].permute([1, 2, 0]) / 2 + 0.5)

# %%
batch[0].shape
# Out:
# torch.Size([3, 256, 256])

# %% [markdown]
# # Encode

# %%
cond = model.encode(batch.to(device))
xT = model.encode_stochastic(batch.to(device), cond, T=250)

# %%
cond.shape
# Out:
# torch.Size([1, 512])

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ori = (batch + 1) / 2
ax[0].imshow(ori[0].permute(1, 2, 0).cpu())
ax[1].imshow(xT[0].permute(1, 2, 0).cpu())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Decode

# %%
pred = model.render(xT, cond, T=20)
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ori = (batch + 1) / 2
ax[0].imshow(ori[0].permute(1, 2, 0).cpu())
ax[1].imshow(pred[0].permute(1, 2, 0).cpu())
